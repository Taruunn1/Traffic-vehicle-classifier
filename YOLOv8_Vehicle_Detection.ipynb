# %% [markdown]
# # 🚗 YOLOv8 Traffic Vehicle Detection
# ## Real-time Video Processing for Vehicle Classification
#
# This notebook trains and uses **YOLOv8** for detecting and classifying vehicles in video streams.
#
# **Key Features:**
# - ✅ Real-time vehicle detection
# - ✅ Multiple instances per frame
# - ✅ Bounding box annotations
# - ✅ Confidence scores
# - ✅ Video output with detections
# - ✅ Emergency vehicle priority detection

# %% [markdown]
# ## Section 1: Install & Import Required Libraries

# %%
# Install YOLOv8
# !pip install -q ultralytics opencv-python-headless pillow numpy

# %%
# Import Required Libraries
from ultralytics import YOLO
import cv2
import numpy as np
from pathlib import Path
import os

print("✅ All libraries imported successfully!")

# %% [markdown]
# ## Section 2: Load YOLOv8 Model
# Load a pre-trained YOLOv8 model (nano/small/medium/large) using the `YOLO` class.

# %%
# Choose a YOLOv8 model: 'yolov8n.pt' (nano), 'yolov8s.pt' (small), 'yolov8m.pt' (medium)
model = YOLO('yolov8n.pt')  # Change to 'yolov8s.pt' for better accuracy
print('✅ YOLOv8 model loaded:', model)
